# %% [markdown]
# Koodi Hamletin enkulle

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')  
nltk.download('omw-1.4') 
nltk.download('stopwords')  

file1 = open("hamletEn.txt", "r")


play = [[],
        [],
        [],
        [],
        []]

act = 0

#skips the play information
while True:
    line = file1.readline() 
    if line:
        try:
            if (line[0]+line[1]+line[2]) == "ACT":
                break
            else:
                pass       
        except IndexError:
            pass
            
#get sentences. Contains stage directions
while True:
    line = file1.readline() 
    if line:
        try:
            if (line[0]+line[1]+line[2]) == "ACT":
                act += 1
            if (line[0]+line[1]+line[2]+line[3]+line[4]+line[5]) == "HAMLET":
                if line.split("HAMLET", 1)[1] != "\n":
                    play[act].append(line.split("HAMLET", 1)[1].rstrip())
                line = file1.readline()
                while line and line != '\n' :
                    play[act].append(line.rstrip())
                    line = file1.readline()
        except IndexError:
            pass
    else :
        file1.close()
        break 

#remove stage direction

noDirectPlay = [[x for x in play[0] if "[" not in x],
                [x for x in play[1] if "[" not in x],
                [x for x in play[2] if "[" not in x],
                [x for x in play[3] if "[" not in x],
                [x for x in play[4] if "[" not in x]]

#remove special characters
whitelist = set('abcdefghijklmnopqrstuvwxyz ABCDEFGHIJKLMNOPQRSTUVWXYZ')

noSpecialChar = [[''.join(filter(whitelist.__contains__, x)) for x in noDirectPlay[0]],
                 [''.join(filter(whitelist.__contains__, x)) for x in noDirectPlay[1]],
                 [''.join(filter(whitelist.__contains__, x)) for x in noDirectPlay[2]],
                 [''.join(filter(whitelist.__contains__, x)) for x in noDirectPlay[3]],
                 [''.join(filter(whitelist.__contains__, x)) for x in noDirectPlay[4]]]

#make everything lower case

allLower = [[ x.lower() for x in noSpecialChar[0]],
            [ x.lower() for x in noSpecialChar[1]],
            [ x.lower() for x in noSpecialChar[2]],
            [ x.lower() for x in noSpecialChar[3]],
            [ x.lower() for x in noSpecialChar[4]]]

#tokenize

tokens = [[ nltk.word_tokenize(x) for x in allLower[0]],
          [ nltk.word_tokenize(x) for x in allLower[1]],
          [ nltk.word_tokenize(x) for x in allLower[2]],
          [ nltk.word_tokenize(x) for x in allLower[3]],
          [ nltk.word_tokenize(x) for x in allLower[4]]]
        
#remove stopwords

stop_words = set(line.strip() for line in open('stop_words_english.txt'))
noStopw = [[],
           [],
           [],
           [],
           []]

a = 0

for act in tokens:
    for line in act:
        for word in line:
            if word not in stop_words:
                noStopw[a].append(word)
    a += 1


#lemmatization
lemmatizer = WordNetLemmatizer()

lemma = [[ lemmatizer.lemmatize(x) for x in noStopw[0]],
         [ lemmatizer.lemmatize(x) for x in noStopw[1]],
         [ lemmatizer.lemmatize(x) for x in noStopw[2]],
         [ lemmatizer.lemmatize(x) for x in noStopw[3]],
         [ lemmatizer.lemmatize(x) for x in noStopw[4]]]

#remove act seperation
words = []
for act in lemma:
    for word in act:
        words.append(word)

#unique words only
def unique(list1):
  
    # initialize a null list
    unique_list = []
  
    # traverse for all elements
    for x in list1:
        # check if exists in unique_list or not
        if x not in unique_list:
            unique_list.append(x)
    # print list
    return unique_list

unique = unique(words)

print(unique)
# Out:
# [nltk_data] Downloading package wordnet to /home/kali/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/kali/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/kali/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_13732/2885657680.py in <module>
#      19 #skips the play information
#      20 while True:
# ---> 21     line = file1.readline()
#      22     if line:
#      23         try:
#
# /usr/lib/python3.10/codecs.py in decode(self, input, final)
#     317         raise NotImplementedError
#     318
# --> 319     def decode(self, input, final=False):
#     320         # decode input (taking the buffer into account)
# ...

# %% [markdown]
# Koodi hamletin ranskalle

# %%
import spacy

file1 = open("HamletFr.txt", "r")


playFR =[[],
         [],
         [],
         [],
         []]

act = 0

#skips the play information
while True:
    line = file1.readline() 
    if line:
        try:
            if (line[0]+line[1]+line[2]+line[3]) == "ACTE":
                break
            else:
                pass       
        except IndexError:
            pass
            
#get sentences
while True:
    line = file1.readline() 
    if line:
        try:
            if (line[0]+line[1]+line[2]+line[3]) == "ACTE":
                act += 1
            if (line[0]+line[1]+line[2]+line[3]+line[4]+line[5]) == "HAMLET":
                if line.split("— ", 1)[1] != "\n":
                    playFR [act].append(line.split("— ", 1)[1].rstrip())
                line = file1.readline()
                while line and line != '\n' :
                    playFR [act].append(line.rstrip())
                    line = file1.readline()
        except IndexError:
            pass
    else :
        file1.close()
        break 


#remove special characters
whitelist = set('abcdefghijklmnopqrstuvwxyzàâèéêëîïôùûüç\'- ÀÂÈÉÊËÎÏÔABCDEFGHIJKLMNOPQRSTUVWXYZ')

noSpecialCharFR  = [[''.join(filter(whitelist.__contains__, x)) for x in playFR[0]],
                    [''.join(filter(whitelist.__contains__, x)) for x in playFR[1]],
                    [''.join(filter(whitelist.__contains__, x)) for x in playFR[2]],
                    [''.join(filter(whitelist.__contains__, x)) for x in playFR[3]],
                    [''.join(filter(whitelist.__contains__, x)) for x in playFR[4]]]

#make everything lower case

allLowerFR  = [[ x.lower() for x in noSpecialCharFR[0]],
               [ x.lower() for x in noSpecialCharFR[1]],
               [ x.lower() for x in noSpecialCharFR[2]],
               [ x.lower() for x in noSpecialCharFR[3]],
               [ x.lower() for x in noSpecialCharFR[4]]]

#tokenize

tokensFR = [[ nltk.word_tokenize(x) for x in allLowerFR[0]],
            [ nltk.word_tokenize(x) for x in allLowerFR[1]],
            [ nltk.word_tokenize(x) for x in allLowerFR[2]],
            [ nltk.word_tokenize(x) for x in allLowerFR[3]],
            [ nltk.word_tokenize(x) for x in allLowerFR[4]]]
        
#remove stopwords

stop_wordsFR = set(line.strip() for line in open('stop_words_french.txt'))
noStopwFR = [[],
             [],
             [],
             [],
             []]

a = 0

for act in tokensFR:
    for line in act:
        for word in line:
            if word not in stop_words:
                noStopwFR[a].append(word)
    a += 1


#lemmatization. Removes act seperation

nlp = spacy.load('fr_core_news_md')

lemmaFR = []

for act in noStopwFR:
    for line in act:
        doc = nlp(line)
        for token in doc:
            lemmaFR.append(token.lemma_)


uniqueFR = unique(lemmaFR)
# Out:
# Running cells with 'Python 2.7.18 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python2 -m pip install ipykernel -U --user --force-reinstall'
